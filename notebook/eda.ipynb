# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load Data
credit_df = pd.read_csv('../data/creditcard.csv')
fraud_df = pd.read_csv('../data/Fraud_Data.csv')
ip_df = pd.read_csv('../data/IpAddress_to_Country.csv')

# %%
# Check data
credit_df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
fraud_df.describe()
# Out:
#              user_id  purchase_value            age    ip_address  \
# count  151112.000000   151112.000000  151112.000000  1.511120e+05
# mean   200171.040970       36.935372      33.140704  2.152145e+09
# std    115369.285024       18.322762       8.617733  1.248497e+09
# min         2.000000        9.000000      18.000000  5.209350e+04
# 25%    100642.500000       22.000000      27.000000  1.085934e+09
# 50%    199958.000000       35.000000      33.000000  2.154770e+09
# 75%    300054.000000       49.000000      39.000000  3.243258e+09
# max    400000.000000      154.000000      76.000000  4.294850e+09
#
#                class
# count  151112.000000
# mean        0.093646
# std         0.291336
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
ip_df.describe()
# Out:
#        lower_bound_ip_address  upper_bound_ip_address
# count            1.388460e+05            1.388460e+05
# mean             2.724532e+09            2.724557e+09
# std              8.975215e+08            8.974979e+08
# min              1.677722e+07            1.677747e+07
# 25%              1.919930e+09            1.920008e+09
# 50%              3.230887e+09            3.230888e+09
# 75%              3.350465e+09            3.350466e+09
# max              3.758096e+09            3.758096e+09

# %%
# Check for missing values
print("Credit Card")
print(credit_df.isnull().sum())
print("")

print("Fraud Data")
print(fraud_df.isnull().sum())
print("")

print("IP Address to Country")
print(ip_df.isnull().sum())
print("")
# Out:
# Credit Card
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64
#
# Fraud Data
# user_id           0
# signup_time       0
# purchase_time     0
# purchase_value    0
# device_id         0
# source            0
# browser           0
# sex               0
# age               0
# ip_address        0
# class             0
# dtype: int64
#
# IP Address to Country
# lower_bound_ip_address    0
# upper_bound_ip_address    0
# country                   0
# dtype: int64

# %%
# Perform EDA
print("\n Credit Card Info")
print(credit_df.info())

print("\n Fraud Data Info")
print(fraud_df.info())

print("\n IP to Country")
print(ip_df.info())
# Out:
#  Credit Card Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
# ...

# %%
fraud_df.signup_time = pd.to_datetime(fraud_df.signup_time)
fraud_df.purchase_time = pd.to_datetime(fraud_df.purchase_time)

# %%
fraud_df.head()
# Out:
#    user_id         signup_time       purchase_time  purchase_value  \
# 0    22058 2015-02-24 22:55:49 2015-04-18 02:47:11              34
# 1   333320 2015-06-07 20:39:50 2015-06-08 01:38:54              16
# 2     1359 2015-01-01 18:52:44 2015-01-01 18:52:45              15
# 3   150084 2015-04-28 21:13:25 2015-05-04 13:54:50              44
# 4   221365 2015-07-21 07:09:52 2015-09-09 18:40:53              39
#
#        device_id source browser sex  age    ip_address  class
# 0  QVPSPJUOCKZAR    SEO  Chrome   M   39  7.327584e+08      0
# 1  EOGFQPIZPYXFZ    Ads  Chrome   F   53  3.503114e+08      0
# 2  YSSKYOSJHPPLJ    SEO   Opera   M   53  2.621474e+09      1
# 3  ATGTXKYKUDUQN    SEO  Safari   M   41  3.840542e+09      0
# 4  NAUITBZFJKHWW    Ads  Safari   M   45  4.155831e+08      0

# %%
# Visualize 

# Fraud distribution in Fraud_Data.csv
plt.figure(figsize=(6, 4))
sns.countplot(x='class', data=fraud_df, palette='coolwarm')
plt.title("Fraudulent vs. Non-Fraudulent Transactions (E-commerce)")
plt.xlabel("Class (0 = Legit, 1 = Fraud)")
plt.ylabel("Count")
plt.show()

# Fraud distribution in CreditCard.csv
plt.figure(figsize=(6, 4))
sns.countplot(x='Class', data=credit_df, palette='coolwarm')
plt.title("Fraudulent vs. Non-Fraudulent Transactions (Bank)")
plt.xlabel("Class (0 = Legit, 1 = Fraud)")
plt.ylabel("Count")
plt.show()
# Out:
# /var/folders/8q/3jn0l2r571s39320x9v3km1c0000gn/T/ipykernel_10571/3821430974.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='class', data=fraud_df, palette='coolwarm')
# /var/folders/8q/3jn0l2r571s39320x9v3km1c0000gn/T/ipykernel_10571/3821430974.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Class', data=credit_df, palette='coolwarm')

# %%
# Histograms for Fraud_Data.csv
fraud_df.hist(figsize=(12, 8), bins=30, edgecolor="black")
plt.suptitle("Feature Distributions - Fraud Data", fontsize=16)
plt.show()

# Histograms for CreditCard.csv
credit_df.hist(figsize=(12, 8), bins=30, edgecolor="black")
plt.suptitle("Feature Distributions - Credit Card Data", fontsize=16)
plt.show()

# %%
fraud_df['purchase_time'] = pd.to_datetime(fraud_df['purchase_time'])
fraud_df['signup_time'] = pd.to_datetime(fraud_df['signup_time'])

# Extract time-based features
fraud_df["hour_of_day"] = fraud_df["purchase_time"].dt.hour
fraud_df["day_of_week"] = fraud_df["purchase_time"].dt.dayofweek

# Plot fraud transactions over hours of the day
plt.figure(figsize=(6, 4))
sns.countplot(x='hour_of_day', hue='class', data=fraud_df, palette='coolwarm')
plt.title("Fraud vs Non-Fraud Transactions Over Hours")
plt.xlabel("Hour of the Day")
plt.ylabel("Transaction Count")
plt.show()

# %%
# Top devices used in fraud
fraud_transactions = fraud_df[fraud_df["class"] == 1]

plt.figure(figsize=(6, 4))
sns.countplot(y="device_id", data=fraud_transactions, order=fraud_transactions["device_id"].value_counts().index[:10], palette="coolwarm")
plt.title("Top 10 Devices Used for Fraud")
plt.show()
# Out:
# /var/folders/8q/3jn0l2r571s39320x9v3km1c0000gn/T/ipykernel_10571/2930042613.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y="device_id", data=fraud_transactions, order=fraud_transactions["device_id"].value_counts().index[:10], palette="coolwarm")
